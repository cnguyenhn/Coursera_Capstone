# %% [markdown]
# # Table of contents
# * [1. Introduction: Business Problem](#introduction)
# * [2. Data](#data)
# * [3. Methodology](#methodology)
# * [4. Analysis](#analysis)
# * [5. Results and Discussion](#results)
# * [6. Conclusion](#conclusion)

# %% [markdown]
# ## 1. Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# Hochiminh City is the most populous city in Vietnam with a population of 8.4 million (13 million in the metropolitan area) as of 2017. As a major gateway to Vietnam, the city received over 8.6 million international visitors in 2019. Therefor, it would have a very number of potential customer if a restaurant is open.
# So if someone ask to open a Japanese Restaurant in Hochiminh City, where it should be opened so it's profit the best?

# %% [markdown]
# ## 2. Data <a name="data"></a>

# %% [markdown]
# In order to solve the above question, the data of Hochiminh City like district, population, area, population density
# Geolocation data collected from FourSquare wil also be used to collect number of restaurants and their type and location in every neighborhood as well as other venues.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
from pandas.io.json import json_normalize 
from geopy.geocoders import Nominatim
import warnings
warnings.filterwarnings('ignore')
import folium

# %%
address = 'Hochiminh, VN'
geolocator = Nominatim(user_agent="HCM_explorer")
To_location = geolocator.geocode(address)
To_latitude = To_location.latitude
To_longitude = To_location.longitude
print('The geograpical coordinate of Hochiminh City are {}, {}.'.format(To_latitude, To_longitude))
# Out:
# The geograpical coordinate of Hochiminh City are 10.7888764, 106.7034958.

# %% [markdown]
# First, import data of Hochiminh City

# %%
HCM=pd.read_excel('data/HCM.xlsx')
dist_1_latitude=HCM['Latitude'][0]
dist_1_longitude=HCM['Longitude'][0]
HCM.head()
# Out:
#          Name  Area (km2)  Population  Population Density (person/km2)  \
# 0  District 1        7.72      142000                            18394
# 1  District 2       49.79      180000                             3615
# 2  District 3        4.92      190000                            38618
# 3  District 4        4.18      175000                            41866
# 4  District 5        4.27      159000                            37237
#
#     Latitude   Longitude
# 0  10.775659  106.700424
# 1  10.787273  106.749810
# 2  10.784370  106.684409
# 3  10.757826  106.701297
# 4  10.754028  106.663375

# %% [markdown]
# Second, import data from Foursquare

# %%
#Foursquare
CLIENT_ID = 'CTCYFTQL3YTRLS10VQU2WCM00PJPOQQ4JZWKG1U4ICUBCTR3' 
CLIENT_SECRET = '4NVBJ0ZLPKDTB0KDXUCOQW2CZFYRX2A1O150EBFZMSDGADAG'
VERSION = '20180605'
LIMIT = 100 
radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    dist_1_latitude, 
    dist_1_longitude, 
    radius, 
    LIMIT)

url
import requests
results = requests.get(url).json()

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print('Processing ',name,'.....')
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
#get data of all Venue in Ho Chi Minh
HCM_Venues = getNearbyVenues(names=HCM['Name'],
                                   latitudes=HCM['Latitude'],
                                   longitudes=HCM['Longitude']
                                  )
# Out:
# Processing  District 1 .....
# Processing  District 2 .....
# Processing  District 3 .....
# Processing  District 4 .....
# Processing  District 5 .....
# Processing  District 6 .....
# Processing  District 7 .....
# Processing  District 8 .....
# Processing  District 9 .....
# Processing  District 10 .....
# Processing  District 11 .....
# Processing  District 12 .....
# Processing  Binh Tan District .....
# Processing  Binh Thanh District .....
# Processing  Go Vap District .....
# Processing  Phu Nhuan District .....
# Processing  Tan Binh District .....
# Processing  Tan Phu District .....
# Processing  Thu Duc District .....

# %% [markdown]
# We have a data of every venue of HCM:

# %%
HCM_Venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0   District 1              10.775659              106.700424
# 1   District 1              10.775659              106.700424
# 2   District 1              10.775659              106.700424
# 3   District 1              10.775659              106.700424
# 4   District 1              10.775659              106.700424
#
#                                     Venue  Venue Latitude  Venue Longitude  \
# 0          Pasteur Street Brewing Company       10.775220       106.700894
# 1  Liberty Central Saigon Citypoint Hotel       10.774758       106.700795
# 2                    The Old Compass Cafe       10.774816       106.700685
# 3           CGV Cinemas Liberty CityPoint       10.774763       106.700766
# 4                                    O Lé       10.774772       106.699524
#
#        Venue Category
# 0             Brewery
# 1               Hotel
# 2                Café
# 3           Multiplex
# 4  Spanish Restaurant

# %% [markdown]
# Sort all venues which are restaurant only:

# %%
df_restaurant=HCM_Venues[HCM_Venues['Venue Category'].str.contains('Restaurant')]
df_restaurant.reset_index(drop=True,inplace=True)
df_restaurant.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0   District 1              10.775659              106.700424
# 1   District 1              10.775659              106.700424
# 2   District 1              10.775659              106.700424
# 3   District 1              10.775659              106.700424
# 4   District 1              10.775659              106.700424
#
#                 Venue  Venue Latitude  Venue Longitude         Venue Category
# 0                O Lé       10.774772       106.699524     Spanish Restaurant
# 1           Huong Lai       10.777258       106.700219  Vietnamese Restaurant
# 2       Secret Garden       10.777422       106.699926  Vietnamese Restaurant
# 3    Mountain Retreat       10.774370       106.700532  Vietnamese Restaurant
# 4  TukTuk Thai Bistro       10.777389       106.700521        Thai Restaurant

# %% [markdown]
# ## 3. Methodology <a name="methodology"></a>

# %% [markdown]
# In this project, we will invest the data of Hochiminh City like district, population, area, population density  find out if there is any correlation between them and the number of restaurant opened by using FourSquare API. If there is, we can narrow some neightborhoods to open the restaurants.
#
# After that, we will use k-means clustering to segment and cluster the neighborhoods in the city of New York and see what kind of restaurant is opened in district so we can avoid it and choose a better place.

# %% [markdown]
# ## 4. Analysis <a name="analysis"></a>

# %% [markdown]
# ### 4.1 Correlation

# %% [markdown]
# Let's see how many restaurant we have on each District

# %%
df_restaurant_num=df_restaurant['Neighborhood'].value_counts().to_frame()
df_restaurant_num
# Out:
#                      Neighborhood
# District 1                     34
# District 3                     23
# District 4                     12
# District 5                      8
# Tan Binh District               7
# District 7                      6
# District 10                     5
# District 11                     3
# Go Vap District                 2
# District 2                      2
# Phu Nhuan District              2
# District 12                     1
# Binh Thanh District             1

# %% [markdown]
# Let's see how many venues we have on each District

# %%
df_venue_num=HCM_Venues['Neighborhood'].value_counts().to_frame()
df_venue_num
# Out:
#                      Neighborhood
# District 1                    100
# District 3                     40
# District 10                    23
# District 4                     20
# District 5                     19
# Tan Binh District              17
# District 7                     15
# Phu Nhuan District             13
# Binh Thanh District            10
# Thu Duc District                6
# District 6                      5
# District 11                     4
# District 2                      4
# Go Vap District                 4
# District 12                     2
# District 8                      2
# Binh Tan District               1

# %% [markdown]
# Let's add the above info to our dataframe

# %%
df_HCM=pd.merge(HCM,df_restaurant_num,how='left',left_on='Name',right_index=True)
df_HCM.rename(columns={'Neighborhood':'Number of Restaurant'},inplace=True)
df_HCM_new=pd.merge(df_HCM,df_venue_num,how='left',left_on='Name',right_index=True)
df_HCM_new.rename(columns={'Neighborhood':'Number of Venue'},inplace=True)
df_HCM_new.fillna(value=0,inplace=True)
# Out:
#                    Name  Area (km2)  Population  \
# 0            District 1        7.72      142000
# 1            District 2       49.79      180000
# 2            District 3        4.92      190000
# 3            District 4        4.18      175000
# 4            District 5        4.27      159000
# 5            District 6        7.14      233000
# 6            District 7       35.69      360000
# 7            District 8       19.11      424000
# 8            District 9      114.00      397000
# 9           District 10        5.72      234000
# 10          District 11        5.14      209000
# 11          District 12       52.74      620000
# 12    Binh Tan District       52.02      784000
# 13  Binh Thanh District       20.78      499000
# 14      Go Vap District       19.73      676000
# 15   Phu Nhuan District        4.88      163000
# 16    Tan Binh District       22.43      474000
#
#     Population Density (person/km2)   Latitude   Longitude  \
# 0                             18394  10.775659  106.700424
# 1                              3615  10.787273  106.749810
# 2                             38618  10.784370  106.684409
# 3                             41866  10.757826  106.701297
# 4                             37237  10.754028  106.663375
# 5                             32633  10.748093  106.635236
# 6                             10087  10.734034  106.721579
# 7                             22187  10.724088  106.628626
# 8                              3482  10.842840  106.828685
# 9                             40909  10.774596  106.667954
# 10                            40661  10.762974  106.650084
# 11                            11756  10.867153  106.641332
# 12                            15071  10.765258  106.603853
# 13                            24013  10.810583  106.709142
# 14                            34263  10.838678  106.665290
# 15                            33402  10.799194  106.680264
# 16                            21132  10.801466  106.652597
#
#     Number of Restaurant  Number of Venue
# 0                   34.0            100.0
# 1                    2.0              4.0
# 2                   23.0             40.0
# 3                   12.0             20.0
# 4                    8.0             19.0
# 5                    0.0              5.0
# 6                    6.0             15.0
# 7                    0.0              2.0
# 8                    0.0              0.0
# 9                    5.0             23.0
# 10                   3.0              4.0
# 11                   1.0              2.0
# 12                   0.0              1.0
# 13                   1.0             10.0
# 14                   2.0              4.0
# 15                   2.0             13.0
# 16                   7.0             17.0

# %%
df_HCM_new.head(18)
# Out:
#                    Name  Area (km2)  Population  \
# 0            District 1        7.72      142000
# 1            District 2       49.79      180000
# 2            District 3        4.92      190000
# 3            District 4        4.18      175000
# 4            District 5        4.27      159000
# 5            District 6        7.14      233000
# 6            District 7       35.69      360000
# 7            District 8       19.11      424000
# 8            District 9      114.00      397000
# 9           District 10        5.72      234000
# 10          District 11        5.14      209000
# 11          District 12       52.74      620000
# 12    Binh Tan District       52.02      784000
# 13  Binh Thanh District       20.78      499000
# 14      Go Vap District       19.73      676000
# 15   Phu Nhuan District        4.88      163000
# 16    Tan Binh District       22.43      474000
# 17     Tan Phu District       15.97      485000
#
#     Population Density (person/km2)   Latitude   Longitude  \
# 0                             18394  10.775659  106.700424
# 1                              3615  10.787273  106.749810
# 2                             38618  10.784370  106.684409
# 3                             41866  10.757826  106.701297
# 4                             37237  10.754028  106.663375
# 5                             32633  10.748093  106.635236
# 6                             10087  10.734034  106.721579
# 7                             22187  10.724088  106.628626
# 8                              3482  10.842840  106.828685
# 9                             40909  10.774596  106.667954
# 10                            40661  10.762974  106.650084
# 11                            11756  10.867153  106.641332
# 12                            15071  10.765258  106.603853
# 13                            24013  10.810583  106.709142
# 14                            34263  10.838678  106.665290
# 15                            33402  10.799194  106.680264
# 16                            21132  10.801466  106.652597
# 17                            30369  11.427531  107.361230
#
#     Number of Restaurant  Number of Venue
# 0                   34.0            100.0
# 1                    2.0              4.0
# 2                   23.0             40.0
# 3                   12.0             20.0
# 4                    8.0             19.0
# 5                    0.0              5.0
# 6                    6.0             15.0
# 7                    0.0              2.0
# 8                    0.0              0.0
# 9                    5.0             23.0
# 10                   3.0              4.0
# 11                   1.0              2.0
# 12                   0.0              1.0
# 13                   1.0             10.0
# 14                   2.0              4.0
# 15                   2.0             13.0
# 16                   7.0             17.0
# 17                   0.0              0.0

# %% [markdown]
# let's see the correlation between the number of Restaurant with the rest info:

# %%
from scipy import stats
df_HCM_new.corr().loc['Number of Restaurant']
# Out:
# Area (km2)                        -0.371799
# Population                        -0.495202
# Population Density (person/km2)    0.189533
# Latitude                          -0.197038
# Longitude                         -0.129953
# Number of Restaurant               1.000000
# Number of Venue                    0.950511
# Name: Number of Restaurant, dtype: float64

# %% [markdown]
# We found that the correlation coefficient between Number of Restaurant and Population, and between Number of Restaurant and Number of Venue are noticable: -0.495202, 0.950511. So let check their P-value:

# %%
pearson_coef, p_value = stats.pearsonr(df_HCM_new['Number of Restaurant'],df_HCM_new['Population'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value )
# Out:
# The Pearson Correlation Coefficient is -0.49520242127936664  with a P-value of P = 0.03109951445332337

# %% [markdown]
# **=> there is a moderate relation between Number of Restaurant and Population**

# %%
pearson_coef, p_value = stats.pearsonr(df_HCM_new['Number of Restaurant'],df_HCM_new['Number of Venue'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.95051089106888  with a P-value of P = 4.672574022418637e-10

# %% [markdown]
# **=> there is a strong relation between Number of Restaurant and Number of Venue**

# %% [markdown]
# Top 5 district have high Number of Venue:

# %%
df_HCM_new.sort_values(by=['Number of Venue'],ascending=False).head()
# Out:
#           Name  Area (km2)  Population  Population Density (person/km2)  \
# 0   District 1        7.72      142000                            18394
# 2   District 3        4.92      190000                            38618
# 9  District 10        5.72      234000                            40909
# 3   District 4        4.18      175000                            41866
# 4   District 5        4.27      159000                            37237
#
#     Latitude   Longitude  Number of Restaurant  Number of Venue
# 0  10.775659  106.700424                  34.0            100.0
# 2  10.784370  106.684409                  23.0             40.0
# 9  10.774596  106.667954                   5.0             23.0
# 3  10.757826  106.701297                  12.0             20.0
# 4  10.754028  106.663375                   8.0             19.0

# %% [markdown]
# ### 4.2 K-means

# %% [markdown]
# Let's see how many kind of restaurant in Hochiminh City:

# %%
df_restaurant.groupby('Neighborhood').count().iloc[:,0]
# Out:
# Neighborhood
# Binh Thanh District     1
# District 1             34
# District 10             5
# District 11             3
# District 12             1
# District 2              2
# District 3             23
# District 4             12
# District 5              8
# District 7              6
# Go Vap District         2
# Phu Nhuan District      2
# Tan Binh District       7
# Name: Neighborhood Latitude, dtype: int64

# %%
print('There are {} uniques categories.'.format(len(df_restaurant['Venue Category'].unique())))
# Out:
# There are 23 uniques categories.

# %%
# one hot encoding
HCM_onehot = pd.get_dummies(df_restaurant[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
HCM_onehot['Neighborhood'] = df_restaurant['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [HCM_onehot.columns[-1]] + list(HCM_onehot.columns[:-1])
HCM_onehot = HCM_onehot[fixed_columns]

HCM_onehot.head()
# Out:
#   Neighborhood  Argentinian Restaurant  Asian Restaurant  Chinese Restaurant  \
# 0   District 1                       0                 0                   0
# 1   District 1                       0                 0                   0
# 2   District 1                       0                 0                   0
# 3   District 1                       0                 0                   0
# 4   District 1                       0                 0                   0
#
#    Dim Sum Restaurant  Eastern European Restaurant  Fast Food Restaurant  \
# 0                   0                            0                     0
# 1                   0                            0                     0
# 2                   0                            0                     0
# 3                   0                            0                     0
# 4                   0                            0                     0
#
#    French Restaurant  German Restaurant  Hawaiian Restaurant  ...  \
# 0                  0                  0                    0  ...
# 1                  0                  0                    0  ...
# 2                  0                  0                    0  ...
# 3                  0                  0                    0  ...
# 4                  0                  0                    0  ...
#
#    Middle Eastern Restaurant  North Indian Restaurant  Restaurant  \
# 0                          0                        0           0
# 1                          0                        0           0
# 2                          0                        0           0
# 3                          0                        0           0
# 4                          0                        0           0
#
#    Scandinavian Restaurant  Seafood Restaurant  Spanish Restaurant  \
# 0                        0                   0                   1
# 1                        0                   0                   0
# 2                        0                   0                   0
# 3                        0                   0                   0
# 4                        0                   0                   0
#
#    Sushi Restaurant  Thai Restaurant  Vegetarian / Vegan Restaurant  \
# 0                 0                0                              0
# 1                 0                0                              0
# 2                 0                0                              0
# 3                 0                0                              0
# 4                 0                1                              0
#
#    Vietnamese Restaurant
# 0                      0
# 1                      1
# 2                      1
# 3                      1
# 4                      0
#
# [5 rows x 24 columns]

# %%
HCM_grouped = HCM_onehot.groupby('Neighborhood').mean().reset_index()
HCM_grouped.head()
# Out:
#           Neighborhood  Argentinian Restaurant  Asian Restaurant  \
# 0  Binh Thanh District                0.000000          0.000000
# 1           District 1                0.029412          0.058824
# 2          District 10                0.000000          0.000000
# 3          District 11                0.000000          0.333333
# 4          District 12                0.000000          0.000000
#
#    Chinese Restaurant  Dim Sum Restaurant  Eastern European Restaurant  \
# 0                 0.0                 0.0                     0.000000
# 1                 0.0                 0.0                     0.029412
# 2                 0.0                 0.0                     0.000000
# 3                 0.0                 0.0                     0.000000
# 4                 0.0                 0.0                     0.000000
#
#    Fast Food Restaurant  French Restaurant  German Restaurant  \
# 0                   0.0           0.000000           0.000000
# 1                   0.0           0.029412           0.029412
# 2                   0.0           0.000000           0.000000
# 3                   0.0           0.000000           0.000000
# 4                   0.0           0.000000           0.000000
#
#    Hawaiian Restaurant  ...  Middle Eastern Restaurant  \
# 0             0.000000  ...                   0.000000
# 1             0.029412  ...                   0.029412
# 2             0.000000  ...                   0.000000
# 3             0.000000  ...                   0.000000
# 4             0.000000  ...                   0.000000
#
#    North Indian Restaurant  Restaurant  Scandinavian Restaurant  \
# 0                 0.000000    0.000000                      0.0
# 1                 0.029412    0.058824                      0.0
# 2                 0.000000    0.000000                      0.0
# 3                 0.000000    0.000000                      0.0
# 4                 0.000000    1.000000                      0.0
#
#    Seafood Restaurant  Spanish Restaurant  Sushi Restaurant  Thai Restaurant  \
# 0            0.000000            0.000000          0.000000         0.000000
# 1            0.000000            0.029412          0.058824         0.058824
# 2            0.000000            0.000000          0.000000         0.000000
# 3            0.333333            0.000000          0.000000         0.000000
# 4            0.000000            0.000000          0.000000         0.000000
#
#    Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 0                       0.000000               1.000000
# 1                       0.029412               0.352941
# 2                       0.000000               0.800000
# 3                       0.000000               0.333333
# 4                       0.000000               0.000000
#
# [5 rows x 24 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Ok, we now can see the frequency of different kind of restaurant in each District:

# %%
num_top_venues = 5

for hood in HCM_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = HCM_grouped[HCM_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Binh Thanh District----
#                            venue  freq
# 0          Vietnamese Restaurant   1.0
# 1             Mexican Restaurant   0.0
# 2  Vegetarian / Vegan Restaurant   0.0
# 3                Thai Restaurant   0.0
# 4               Sushi Restaurant   0.0
#
#
# ----District 1----
#                    venue  freq
# 0  Vietnamese Restaurant  0.35
# 1    Japanese Restaurant  0.06
# 2        Thai Restaurant  0.06
# 3       Sushi Restaurant  0.06
# 4             Restaurant  0.06
#
#
# ----District 10----
#                            venue  freq
# 0          Vietnamese Restaurant   0.8
# 1              Korean Restaurant   0.2
# 2             Chinese Restaurant   0.0
# 3      Middle Eastern Restaurant   0.0
# 4  Vegetarian / Vegan Restaurant   0.0
#
#
# ----District 11----
#                            venue  freq
# 0          Vietnamese Restaurant  0.33
# 1             Seafood Restaurant  0.33
# 2               Asian Restaurant  0.33
# 3             Mexican Restaurant  0.00
# 4  Vegetarian / Vegan Restaurant  0.00
#
#
# ----District 12----
#                            venue  freq
# 0                     Restaurant   1.0
# 1         Argentinian Restaurant   0.0
# 2             Mexican Restaurant   0.0
# 3  Vegetarian / Vegan Restaurant   0.0
# 4                Thai Restaurant   0.0
#
#
# ----District 2----
#                            venue  freq
# 0          Vietnamese Restaurant   1.0
# 1             Mexican Restaurant   0.0
# 2  Vegetarian / Vegan Restaurant   0.0
# 3                Thai Restaurant   0.0
# 4               Sushi Restaurant   0.0
#
#
# ----District 3----
#                    venue  freq
# 0  Vietnamese Restaurant  0.52
# 1      French Restaurant  0.17
# 2     Seafood Restaurant  0.13
# 3       Asian Restaurant  0.13
# 4      Korean Restaurant  0.04
#
#
# ----District 4----
#                            venue  freq
# 0             Seafood Restaurant  0.50
# 1              Korean Restaurant  0.08
# 2            Japanese Restaurant  0.08
# 3  Vegetarian / Vegan Restaurant  0.08
# 4             Mexican Restaurant  0.08
#
#
# ----District 5----
#                        venue  freq
# 0         Chinese Restaurant  0.38
# 1      Vietnamese Restaurant  0.25
# 2         Dim Sum Restaurant  0.25
# 3           Asian Restaurant  0.12
# 4  Middle Eastern Restaurant  0.00
#
#
# ----District 7----
#                      venue  freq
# 0    Vietnamese Restaurant  0.50
# 1         Sushi Restaurant  0.17
# 2  Scandinavian Restaurant  0.17
# 3      Japanese Restaurant  0.17
# 4       Mexican Restaurant  0.00
#
#
# ----Go Vap District----
#                            venue  freq
# 0          Vietnamese Restaurant   0.5
# 1           Fast Food Restaurant   0.5
# 2             Mexican Restaurant   0.0
# 3  Vegetarian / Vegan Restaurant   0.0
# 4                Thai Restaurant   0.0
#
#
# ----Phu Nhuan District----
#                            venue  freq
# 0          Vietnamese Restaurant   1.0
# 1             Mexican Restaurant   0.0
# 2  Vegetarian / Vegan Restaurant   0.0
# 3                Thai Restaurant   0.0
# 4               Sushi Restaurant   0.0
#
#
# ----Tan Binh District----
#                    venue  freq
# 0  Vietnamese Restaurant  0.43
# 1       Sushi Restaurant  0.14
# 2     Seafood Restaurant  0.14
# 3             Restaurant  0.14
# 4       Asian Restaurant  0.14

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Restaurant'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Restaurant'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = HCM_grouped['Neighborhood']

for ind in np.arange(HCM_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(HCM_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#            Neighborhood 1st Most Common Restaurant 2nd Most Common Restaurant  \
# 0   Binh Thanh District      Vietnamese Restaurant        Japanese Restaurant
# 1            District 1      Vietnamese Restaurant                 Restaurant
# 2           District 10      Vietnamese Restaurant          Korean Restaurant
# 3           District 11      Vietnamese Restaurant           Asian Restaurant
# 4           District 12                 Restaurant      Vietnamese Restaurant
# 5            District 2      Vietnamese Restaurant        Japanese Restaurant
# 6            District 3      Vietnamese Restaurant          French Restaurant
# 7            District 4         Seafood Restaurant      Vietnamese Restaurant
# 8            District 5         Chinese Restaurant      Vietnamese Restaurant
# 9            District 7      Vietnamese Restaurant           Sushi Restaurant
# 10      Go Vap District      Vietnamese Restaurant       Fast Food Restaurant
# 11   Phu Nhuan District      Vietnamese Restaurant        Japanese Restaurant
# 12    Tan Binh District      Vietnamese Restaurant           Asian Restaurant
#
#    3rd Most Common Restaurant 4th Most Common Restaurant  \
# 0            Asian Restaurant         Chinese Restaurant
# 1            Asian Restaurant        Japanese Restaurant
# 2             Thai Restaurant         Italian Restaurant
# 3          Seafood Restaurant        Japanese Restaurant
# 4         Japanese Restaurant           Asian Restaurant
# 5            Asian Restaurant         Chinese Restaurant
# 6          Seafood Restaurant           Asian Restaurant
# 7          Mexican Restaurant       Fast Food Restaurant
# 8          Dim Sum Restaurant           Asian Restaurant
# 9     Scandinavian Restaurant        Japanese Restaurant
# 10        Japanese Restaurant           Asian Restaurant
# 11           Asian Restaurant         Chinese Restaurant
# 12           Sushi Restaurant         Seafood Restaurant
#
#    5th Most Common Restaurant
# 0          Dim Sum Restaurant
# 1           Korean Restaurant
# 2            Asian Restaurant
# 3          Chinese Restaurant
# 4          Chinese Restaurant
# 5          Dim Sum Restaurant
# 6           Korean Restaurant
# 7         Japanese Restaurant
# 8         Japanese Restaurant
# 9          Italian Restaurant
# 10         Chinese Restaurant
# 11         Dim Sum Restaurant
# 12                 Restaurant

# %%
from sklearn.cluster import KMeans #importing KMeans

kclusters = 5
HCM_grouped_clustering = HCM_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(HCM_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 3, 0, 1, 2, 0, 3, 1, 3, 3])

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_) # add clustering labels

# %%
neighborhoods_venues_sorted.head()
# Out:
#    Cluster Labels         Neighborhood 1st Most Common Restaurant  \
# 0               0  Binh Thanh District      Vietnamese Restaurant
# 1               3           District 1      Vietnamese Restaurant
# 2               0          District 10      Vietnamese Restaurant
# 3               1          District 11      Vietnamese Restaurant
# 4               2          District 12                 Restaurant
#
#   2nd Most Common Restaurant 3rd Most Common Restaurant  \
# 0        Japanese Restaurant           Asian Restaurant
# 1                 Restaurant           Asian Restaurant
# 2          Korean Restaurant            Thai Restaurant
# 3           Asian Restaurant         Seafood Restaurant
# 4      Vietnamese Restaurant        Japanese Restaurant
#
#   4th Most Common Restaurant 5th Most Common Restaurant
# 0         Chinese Restaurant         Dim Sum Restaurant
# 1        Japanese Restaurant          Korean Restaurant
# 2         Italian Restaurant           Asian Restaurant
# 3        Japanese Restaurant         Chinese Restaurant
# 4           Asian Restaurant         Chinese Restaurant

# %%
df_HCM_new.head()
# Out:
#          Name  Area (km2)  Population  Population Density (person/km2)  \
# 0  District 1        7.72      142000                            18394
# 1  District 2       49.79      180000                             3615
# 2  District 3        4.92      190000                            38618
# 3  District 4        4.18      175000                            41866
# 4  District 5        4.27      159000                            37237
#
#     Latitude   Longitude  Number of Restaurant  Number of Venue
# 0  10.775659  106.700424                  34.0            100.0
# 1  10.787273  106.749810                   2.0              4.0
# 2  10.784370  106.684409                  23.0             40.0
# 3  10.757826  106.701297                  12.0             20.0
# 4  10.754028  106.663375                   8.0             19.0

# %%
# merge HCM_grouped with df_HCM_new to add latitude/longitude for each neighborhood
df_HCM_new = df_HCM_new.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Name',how='inner')

# %% [markdown]
# And now we can see the top 5 common restaurant for each district:

# %%
df_HCM_new
# Out:
#                    Name  Area (km2)  Population  \
# 0            District 1        7.72      142000
# 1            District 2       49.79      180000
# 2            District 3        4.92      190000
# 3            District 4        4.18      175000
# 4            District 5        4.27      159000
# 6            District 7       35.69      360000
# 9           District 10        5.72      234000
# 10          District 11        5.14      209000
# 11          District 12       52.74      620000
# 13  Binh Thanh District       20.78      499000
# 14      Go Vap District       19.73      676000
# 15   Phu Nhuan District        4.88      163000
# 16    Tan Binh District       22.43      474000
#
#     Population Density (person/km2)   Latitude   Longitude  \
# 0                             18394  10.775659  106.700424
# 1                              3615  10.787273  106.749810
# 2                             38618  10.784370  106.684409
# 3                             41866  10.757826  106.701297
# 4                             37237  10.754028  106.663375
# 6                             10087  10.734034  106.721579
# 9                             40909  10.774596  106.667954
# 10                            40661  10.762974  106.650084
# 11                            11756  10.867153  106.641332
# 13                            24013  10.810583  106.709142
# 14                            34263  10.838678  106.665290
# 15                            33402  10.799194  106.680264
# 16                            21132  10.801466  106.652597
#
#     Number of Restaurant  Number of Venue  Cluster Labels  \
# 0                   34.0            100.0               3
# 1                    2.0              4.0               0
# 2                   23.0             40.0               3
# 3                   12.0             20.0               1
# 4                    8.0             19.0               3
# 6                    6.0             15.0               3
# 9                    5.0             23.0               0
# 10                   3.0              4.0               1
# 11                   1.0              2.0               2
# 13                   1.0             10.0               0
# 14                   2.0              4.0               4
# 15                   2.0             13.0               0
# 16                   7.0             17.0               3
#
#    1st Most Common Restaurant 2nd Most Common Restaurant  \
# 0       Vietnamese Restaurant                 Restaurant
# 1       Vietnamese Restaurant        Japanese Restaurant
# 2       Vietnamese Restaurant          French Restaurant
# 3          Seafood Restaurant      Vietnamese Restaurant
# 4          Chinese Restaurant      Vietnamese Restaurant
# 6       Vietnamese Restaurant           Sushi Restaurant
# 9       Vietnamese Restaurant          Korean Restaurant
# 10      Vietnamese Restaurant           Asian Restaurant
# 11                 Restaurant      Vietnamese Restaurant
# 13      Vietnamese Restaurant        Japanese Restaurant
# 14      Vietnamese Restaurant       Fast Food Restaurant
# 15      Vietnamese Restaurant        Japanese Restaurant
# 16      Vietnamese Restaurant           Asian Restaurant
#
#    3rd Most Common Restaurant 4th Most Common Restaurant  \
# 0            Asian Restaurant        Japanese Restaurant
# 1            Asian Restaurant         Chinese Restaurant
# 2          Seafood Restaurant           Asian Restaurant
# 3          Mexican Restaurant       Fast Food Restaurant
# 4          Dim Sum Restaurant           Asian Restaurant
# 6     Scandinavian Restaurant        Japanese Restaurant
# 9             Thai Restaurant         Italian Restaurant
# 10         Seafood Restaurant        Japanese Restaurant
# 11        Japanese Restaurant           Asian Restaurant
# 13           Asian Restaurant         Chinese Restaurant
# 14        Japanese Restaurant           Asian Restaurant
# 15           Asian Restaurant         Chinese Restaurant
# 16           Sushi Restaurant         Seafood Restaurant
#
#    5th Most Common Restaurant
# 0           Korean Restaurant
# 1          Dim Sum Restaurant
# 2           Korean Restaurant
# 3         Japanese Restaurant
# 4         Japanese Restaurant
# 6          Italian Restaurant
# 9            Asian Restaurant
# 10         Chinese Restaurant
# 11         Chinese Restaurant
# 13         Dim Sum Restaurant
# 14         Chinese Restaurant
# 15         Dim Sum Restaurant
# 16                 Restaurant

# %%
# visualize the resulting clusters

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
map_clusters = folium.Map(location=[To_latitude, To_longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df_HCM_new['Latitude'], df_HCM_new['Longitude'], df_HCM_new['Name'], df_HCM_new['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_HCM_new.loc[df_HCM_new['Cluster Labels'] == 0, df_HCM_new.columns[[1] + list(range(5, df_HCM_new.shape[1]))]]
# Out:
#     Area (km2)   Longitude  Number of Restaurant  Number of Venue  \
# 1        49.79  106.749810                   2.0              4.0
# 9         5.72  106.667954                   5.0             23.0
# 13       20.78  106.709142                   1.0             10.0
# 15        4.88  106.680264                   2.0             13.0
#
#     Cluster Labels 1st Most Common Restaurant 2nd Most Common Restaurant  \
# 1                0      Vietnamese Restaurant        Japanese Restaurant
# 9                0      Vietnamese Restaurant          Korean Restaurant
# 13               0      Vietnamese Restaurant        Japanese Restaurant
# 15               0      Vietnamese Restaurant        Japanese Restaurant
#
#    3rd Most Common Restaurant 4th Most Common Restaurant  \
# 1            Asian Restaurant         Chinese Restaurant
# 9             Thai Restaurant         Italian Restaurant
# 13           Asian Restaurant         Chinese Restaurant
# 15           Asian Restaurant         Chinese Restaurant
#
#    5th Most Common Restaurant
# 1          Dim Sum Restaurant
# 9            Asian Restaurant
# 13         Dim Sum Restaurant
# 15         Dim Sum Restaurant

# %%
df_HCM_new.loc[df_HCM_new['Cluster Labels'] == 1, df_HCM_new.columns[[1] + list(range(5, df_HCM_new.shape[1]))]]
# Out:
#     Area (km2)   Longitude  Number of Restaurant  Number of Venue  \
# 3         4.18  106.701297                  12.0             20.0
# 10        5.14  106.650084                   3.0              4.0
#
#     Cluster Labels 1st Most Common Restaurant 2nd Most Common Restaurant  \
# 3                1         Seafood Restaurant      Vietnamese Restaurant
# 10               1      Vietnamese Restaurant           Asian Restaurant
#
#    3rd Most Common Restaurant 4th Most Common Restaurant  \
# 3          Mexican Restaurant       Fast Food Restaurant
# 10         Seafood Restaurant        Japanese Restaurant
#
#    5th Most Common Restaurant
# 3         Japanese Restaurant
# 10         Chinese Restaurant

# %%
df_HCM_new.loc[df_HCM_new['Cluster Labels'] == 2, df_HCM_new.columns[[1] + list(range(5, df_HCM_new.shape[1]))]]
# Out:
#     Area (km2)   Longitude  Number of Restaurant  Number of Venue  \
# 11       52.74  106.641332                   1.0              2.0
#
#     Cluster Labels 1st Most Common Restaurant 2nd Most Common Restaurant  \
# 11               2                 Restaurant      Vietnamese Restaurant
#
#    3rd Most Common Restaurant 4th Most Common Restaurant  \
# 11        Japanese Restaurant           Asian Restaurant
#
#    5th Most Common Restaurant
# 11         Chinese Restaurant

# %%
df_HCM_new.loc[df_HCM_new['Cluster Labels'] == 3, df_HCM_new.columns[[1] + list(range(5, df_HCM_new.shape[1]))]]
# Out:
#     Area (km2)   Longitude  Number of Restaurant  Number of Venue  \
# 0         7.72  106.700424                  34.0            100.0
# 2         4.92  106.684409                  23.0             40.0
# 4         4.27  106.663375                   8.0             19.0
# 6        35.69  106.721579                   6.0             15.0
# 16       22.43  106.652597                   7.0             17.0
#
#     Cluster Labels 1st Most Common Restaurant 2nd Most Common Restaurant  \
# 0                3      Vietnamese Restaurant                 Restaurant
# 2                3      Vietnamese Restaurant          French Restaurant
# 4                3         Chinese Restaurant      Vietnamese Restaurant
# 6                3      Vietnamese Restaurant           Sushi Restaurant
# 16               3      Vietnamese Restaurant           Asian Restaurant
#
#    3rd Most Common Restaurant 4th Most Common Restaurant  \
# 0            Asian Restaurant        Japanese Restaurant
# 2          Seafood Restaurant           Asian Restaurant
# 4          Dim Sum Restaurant           Asian Restaurant
# 6     Scandinavian Restaurant        Japanese Restaurant
# 16           Sushi Restaurant         Seafood Restaurant
#
#    5th Most Common Restaurant
# 0           Korean Restaurant
# 2           Korean Restaurant
# 4         Japanese Restaurant
# 6          Italian Restaurant
# 16                 Restaurant

# %%
df_HCM_new.loc[df_HCM_new['Cluster Labels'] == 4, df_HCM_new.columns[[1] + list(range(5, df_HCM_new.shape[1]))]]
# Out:
#     Area (km2)  Longitude  Number of Restaurant  Number of Venue  \
# 14       19.73  106.66529                   2.0              4.0
#
#     Cluster Labels 1st Most Common Restaurant 2nd Most Common Restaurant  \
# 14               4      Vietnamese Restaurant       Fast Food Restaurant
#
#    3rd Most Common Restaurant 4th Most Common Restaurant  \
# 14        Japanese Restaurant           Asian Restaurant
#
#    5th Most Common Restaurant
# 14         Chinese Restaurant

# %% [markdown]
# ## 5. Results and Discussion <a name="results"></a>

# %% [markdown]
# Our analyst shows that there is a strong relation between Number of Restaurant and Number of Venue. So its seems that the restaurant should be opened where the economy is higher than other place. We can narrow down the top 5 district have highest economy: 1,3,10,4,5. Within these 5 district, the ratio between restaurant's number and Venue's number of district 1, 10 are quite low compare to other place so these 2 districts seem like the place we are looking for.
#
# By using K-means, we found that on District 1, the Japanese restaurant is in the 4th most common Restaurant. So if we open a Japanese restaurant in District 1, there quite a number of rivalry. But in District 10, the Japanese restaurant isn't in top 5 common restaurant so District 10 is likely a place to open the Japanese restaurant.

# %% [markdown]
# ## 6. Conclusion <a name="conclusion"></a>

# %% [markdown]
# Purpose of this project was to identify Hochiminh City area in order to aid stakeholders in narrowing down the search for optimal location for a new Japanese restaurant. By calculating restaurant density distribution from Foursquare data and the relation of between each characteristics of District, we have choose District 10 as the starting point for final decision by stakeholders. The exact location will be made only after stakeholders considers on other characteristics of district like the attractiveness, real estate avalability, estate's price, traffic,...
